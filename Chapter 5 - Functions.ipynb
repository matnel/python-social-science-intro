# %% [markdown]
# **Function** is used to execute several lines of code in any place needed.

# %%
def hello():
    print "Hello world!"
    print "I am a function"
    
hello()
print "Testing... 1"
hello() 
print "Testing... 2"
hello()
print "Testing... 3"
hello() ## used 10 lines of code instead of 11!
# Out:
# Hello world!
# I am a function
# Testing... 1
# Hello world!
# I am a function
# Testing... 2
# Hello world!
# I am a function
# Testing... 3
# Hello world!
# I am a function

# %% [markdown]
# Function can take a **parameter**, that is a variable used inside the execution of that function

# %%
def hello2( number ):
    print "Testing...", number
    print "Hello world!"
    print "I am a function"
    
hello()
hello2(1)
hello2(2)
hello2(3)
# Out:
# Hello world!
# I am a function
# Testing... 1
# Hello world!
# I am a function
# Testing... 2
# Hello world!
# I am a function
# Testing... 3
# Hello world!
# I am a function

# %% [markdown]
# **Racap!** Can the example above be even more simplified? How?

# %% [markdown]
# Functions can also **return** a spesific value that can be used in further processing of the code.

# %%
def maths( a, b, c ):
    return ( a + b ) * c

a = maths( 1, 2, 3 )
b = maths( 3, 2, 1 )
c = maths( 3, 3, 3 )

print a
print b
print c

d = maths( a, b, c)
print d
# Out:
# 9
# 5
# 18
# 252

# %% [markdown]
# **Onboarding**
#
# * Create a function which prints `This function works`
# * Create a function which takes a text parameter and prints it
# * Create a function which takes a text parameter and returns it
# * Create a function which returns `This function works`

# %% [markdown]
# ### Working in Kela
#
# * Define a function, which takes the number of student grant months as input and calculates based on that the maximum income for the student in that year. See Kela page http://www.kela.fi/web/en/student-s-own-income for details.
# * Define a function, which takes the monthly rent paid by the student and returns the housing supplement based on that income. See Kela page http://www.kela.fi/web/en/housing-supplement_amount for details.
# * Use a dictonary to store how much housing supplement is recieved when the rent is 200, 225, 250, 275, and 300 euros.
