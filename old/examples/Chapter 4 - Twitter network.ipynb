# %% [markdown]
# `twitter_network.txt` is a file that shows the mention network under spesific hashtag in Twitter. The file looks like
#
# `2933312565 -> 3152342314
# 434383089 -> 1240030489
# 1116331430 -> -`
#
# i.e. it is in format of `who -> who is mentioned` where `-` means no user was mentioned.

# %% [markdown]
# **Playing around**
#
# * How many tweets are mentioned in the fie?
# * How many tweets mention no user?
# * How many tweets user 24355353 send?

# %%
for line in open('../twitter_network.txt'): ## note, file path changed as we're in a subfolder
    
    line = line.strip() ## remove extra spaces in the begin and end of line
    _from = line.split(' -> ')[0] ## part before ->
    _to = line.split(' -> ')[1] ## part after ->
    
    print _from, _to
# Out:
# 25532553 1039542319
# 2933312565 3152342314
# 434383089 1240030489
# 1116331430 -
# 1901172085 1116331430
# 490652443 1116331430
# 1956084344 -
# 1285917966 -
# 24355353 -
# 2163458821 -
# 2982683315 2375242424
# 24355353 -
# 2296669206 -
# 24355353 -
# 24355353 -
# 468568202 -
# 223639831 2609438242
# 2567547829 2567547829
# 1038990073 -
# 1221232640 -
# 2524187308 -
# 631575413 -
# 2210737688 631575413
# 1886530758 1913798256
# 2999887376 22819556
# 2982683315 2163458821
# 63375824 -
# 25971685 63375824
# 3140017654 63375824
# 493115300 63375824
# 266889468 -
# 24355353 -
# 24355353 -
# 24355353 -
# 24355353 -
# 24355353 -
# 802105477 -
# 3095150410 -
# 24355353 -
# 65134133 -
# 77228561 65134133
# 24355353 -
# 48272803 -
# 2250253762 65134133
# 1077335504 244239390
# 934918560 -
# 2516988633 -
# 848194345 -
# 2392649988 -
# 747780146 -
# 2982683315 848194345
# 2919770145 65134133
# 1313703212 -
# 1401832460 63375824
# 1606060812 -
# 958085023 -
# 1899987524 -
# 1856760744 -
# ...

# %%
line_counter = 0

for line in open('../twitter_network.txt'): ## note, file path changed as we're in a subfolder
    
    line = line.strip() ## remove extra spaces in the begin and end of line
    _from = line.split(' -> ')[0] ## part before ->
    _to = line.split(' -> ')[1] ## part after ->
    
    line_counter = line_counter + 1
    
print line_counter
# Out:
# 1354

# %%
no_user = 0

for line in open('../twitter_network.txt'): ## note, file path changed as we're in a subfolder
    
    line = line.strip() ## remove extra spaces in the begin and end of line
    _from = line.split(' -> ')[0] ## part before ->
    _to = line.split(' -> ')[1] ## part after ->
    
    if _to == '-':
        no_user = no_user + 1
    
print no_user
# Out:
# 750

# %%
user = 0

for line in open('../twitter_network.txt'): ## note, file path changed as we're in a subfolder
    
    line = line.strip() ## remove extra spaces in the begin and end of line
    _from = line.split(' -> ')[0] ## part before ->
    _to = line.split(' -> ')[1] ## part after ->
    
    if _from == '24355353':
        user = user + 1
    
print user
# Out:
# 18
